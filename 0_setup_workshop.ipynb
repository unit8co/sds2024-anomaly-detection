# %%
# setup darts
# !pip install -r requirements.txt
# Out:
# Collecting darts@ git+https://github.com/unit8co/darts.git@master (from -r requirements.txt (line 1))
#   Cloning https://github.com/unit8co/darts.git (to revision master) to /private/var/folders/wl/dxt16jls7jz1_252v4f209780000gp/T/pip-install-a89nbfk8/darts_991b31b8ff7347158bc30df341fb31a2
#   Running command git clone --filter=blob:none --quiet https://github.com/unit8co/darts.git /private/var/folders/wl/dxt16jls7jz1_252v4f209780000gp/T/pip-install-a89nbfk8/darts_991b31b8ff7347158bc30df341fb31a2
#   Resolved https://github.com/unit8co/darts.git to commit a0cc279fe020dc62e991ef936bc934eb7d0051d2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jupyterlab in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (4.2.1)
# Requirement already satisfied: ipywidgets in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (8.1.2)
# Requirement already satisfied: seaborn in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: openpyxl in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: holidays>=0.11.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.49)
# Requirement already satisfied: joblib>=0.16.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: nfoursid>=1.0.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pmdarima>=1.8.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: pyod>=0.9.5 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: requests>=2.22.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.32.2)
# Requirement already satisfied: scikit-learn>=1.0.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: shap>=0.40.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.45.1)
# Requirement already satisfied: statsforecast>=1.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.7.5)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.14.2)
# Requirement already satisfied: tbats>=1.1.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: tqdm>=4.60.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (4.66.4)
# Requirement already satisfied: typing-extensions in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: xarray>=0.17.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2024.5.0)
# Requirement already satisfied: xgboost>=1.6.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: tensorboardX>=2.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.6.2.2)
# Requirement already satisfied: torch>=1.8.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: pandas>=1.0.5 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (6.29.3)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: jupyter-core in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (2.27.2)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: packaging in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (24.0)
# Requirement already satisfied: tornado>=6.2.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (6.3.3)
# Requirement already satisfied: traitlets in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipywidgets->-r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipywidgets->-r requirements.txt (line 3)) (8.24.0)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipywidgets->-r requirements.txt (line 3)) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipywidgets->-r requirements.txt (line 3)) (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from openpyxl->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: python-dateutil in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from holidays>=0.11.1->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: anyio in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 2)) (4.4.0)
# Requirement already satisfied: certifi in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 2)) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: idna in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: sniffio in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: appnope in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 2)) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 2)) (8.6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: psutil in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 2)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 2)) (25.1.2)
# Requirement already satisfied: decorator in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: stack-data in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab->-r requirements.txt (line 2)) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 2)) (4.2.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 2)) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 2)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 2)) (4.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pandas>=1.0.5->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pandas>=1.0.5->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pmdarima>=1.8.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.0.10)
# Requirement already satisfied: urllib3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pmdarima>=1.8.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pmdarima>=1.8.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (69.5.1)
# Requirement already satisfied: numba>=0.51 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pyod>=0.9.5->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.59.1)
# Requirement already satisfied: six in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pyod>=0.9.5->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: PyYAML>=5.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2024.5.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.4.0.post0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from requests>=2.22.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from scikit-learn>=1.0.1->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: slicer==0.0.8 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from shap>=0.40.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.0.8)
# Requirement already satisfied: cloudpickle in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from shap>=0.40.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: coreforecast>=0.0.9 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.0.9)
# Requirement already satisfied: fugue>=0.8.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: utilsforecast>=0.1.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.1.10)
# Requirement already satisfied: patsy>=0.5.6 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from statsmodels>=0.14.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.5.6)
# Requirement already satisfied: protobuf>=3.20 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from tensorboardX>=2.1->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (5.27.0)
# Requirement already satisfied: filelock in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from torch>=1.8.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.14.0)
# Requirement already satisfied: sympy in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from torch>=1.8.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from torch>=1.8.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: argon2-cffi-bindings in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (3.9.5)
# Requirement already satisfied: triad>=0.9.6 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.9.6)
# Requirement already satisfied: adagio>=0.2.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 2)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (2.19.1)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from numba>=0.51->pyod>=0.9.5->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (0.42.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from sympy->torch>=1.8.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: webencodings in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: fqdn in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (2.4)
# Requirement already satisfied: uri-template in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.13)
# Requirement already satisfied: pyarrow>=6.0.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from triad>=0.9.6->fugue>=0.8.1->statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (16.1.0)
# Requirement already satisfied: fs in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from triad>=0.9.6->fugue>=0.8.1->statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (2.4.16)
# Requirement already satisfied: cffi>=1.0.1 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: pycparser in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (2.22)
# Requirement already satisfied: appdirs~=1.4.3 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from fs->triad>=0.9.6->fugue>=0.8.1->statsforecast>=1.4->darts@ git+https://github.com/unit8co/darts.git@master->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: arrow>=0.15.0 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/samuelepiazzetta/miniconda3/envs/sds2024/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 2)) (2.9.0.20240316)

# %%
# Download data from data source to local
import io
import os
import zipfile
import requests

import pandas as pd

# %%
data_dir = "data"
anom_dir = os.path.join(data_dir, "anomaly_detection")
fc_dir = os.path.join(data_dir, "forecasting")
for dir_path in [data_dir, anom_dir, fc_dir]:
    if not os.path.exists(dir_path):
        os.mkdir(dir_path)

# %%
# URL of the zip file
zip_url = "https://my.hidrive.com/api/sharelink/download?id=lmCmAjUP"

file_path = os.path.join(anom_dir, "svdb.zip")
if not os.path.exists(file_path):
    # Send a GET request to download the zip file
    response = requests.get(zip_url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Save the zip file to the local drive
        with open(file_path, "wb") as file:
            file.write(response.content)
        print("Zip file downloaded successfully.")
else:
    print("Zip file already downloaded.")    

# Extract the zip file
with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(anom_dir)
print("Zip file extracted successfully.")
# Out:
# Zip file already downloaded.
# Zip file extracted successfully.

# %%
def download_weather_data():
    """Concatenate the yearly csv files into a single dataframe and reshape it"""
    # download the csv from the url
    base_url = "https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_stundenmittelwerte/download/"
    filenames = [f"ugz_ogd_meteo_h1_{year}.csv" for year in range(2015, 2023)]
    df = pd.concat([pd.read_csv(base_url + fname) for fname in filenames])
    # retain only one weather station
    df = df.loc[df["Standort"] == "Zch_Stampfenbachstrasse"]
    # pivot the df to get all measurements as columns
    df["param_name"] = df["Parameter"] + " [" + df["Einheit"] + "]"
    df = df.pivot(index="Datum", columns="param_name", values="Wert")
    # convert time index to from CET to UTC and extract the required time range
    df.index = pd.DatetimeIndex(pd.to_datetime(df.index, utc=True)).tz_localize(
        None
    )
    df = df.loc[
        (pd.Timestamp("2015-01-01") <= df.index)
        & (df.index <= pd.Timestamp("2022-08-31"))
    ]
    return df

# %%
def download_energy_data():
    # URL of the zip file
    energy_url = "https://data.stadt-zuerich.ch/dataset/ewz_stromabgabe_netzebenen_stadt_zuerich/download/ewz_stromabgabe_netzebenen_stadt_zuerich.csv"
    
    file_path = os.path.join(fc_dir, energy_url.split("/")[-1])
    processed_path = file_path.replace(".csv", "_proc.csv")
    
    if not os.path.exists(processed_path):
        if not os.path.exists(file_path):
            # Send a GET request to download the zip file
            response = requests.get(energy_url)
            
            # Check if the request was successful
            if response.status_code == 200:
                # Save the zip file to the local drive
                with open(file_path, "wb") as file:
                    file.write(response.content)
                print("File downloaded successfully.")
            else:
                raise ValueError("Failed to download.")
        print("Processing file..")
        df = pd.read_csv(file_path, index_col=0)
        # convert time index
        df.index = pd.DatetimeIndex(pd.to_datetime(df.index, utc=True)).tz_localize(None)
        # extract pre-determined period
        df = df.loc[(pd.Timestamp("2015-01-01") <= df.index) & (df.index <= pd.Timestamp("2022-08-31"))]
        # download and preprocess the weather information
        df_weather = download_weather_data()
        # add weather data as additional features
        df = pd.concat([df, df_weather], axis=1)
        # interpolate weather data
        df = df.interpolate()
        # raining duration is given in minutes -> we divide by 4 from hourly to quarter-hourly records
        df["RainDur [min]"] = df["RainDur [min]"] / 4
    
        # round Electricity cols to 4 decimals, other columns to 2 decimals
        cols_precise = ["Value_NE5", "Value_NE7"]
        df = df.round(decimals={col: (4 if col in cols_precise else 2) for col in df.columns})
    
        # export the dataset
        df.index.name = "Timestamp"
        df.to_csv(processed_path)
        os.remove(file_path)
        print("File successfully processed.")
    else:
        print("File already downloaded.")

# %%
download_energy_data()
# Out:
# File already downloaded.
